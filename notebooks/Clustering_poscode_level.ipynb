# %% [markdown]
# # Clustering London

# %% [markdown]
# This is clustering on postcode level phase 1 using standardScaler as standardisation method for both of the models.

# %% [markdown]
# ### DATA PROCESSING AND NORMALISATION

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.cm as cm

from sklearn.preprocessing import StandardScaler

from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.metrics import davies_bouldin_score

from sklearn.decomposition import PCA

from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
# CLEAN DATA FOR CLUSTERING
# Define the path to the CSV file
file_path = "/Users/alessandrosuarez_/Desktop/lastYRofUniShii/IndividualProjectIN3007/Deliverables/Workspace/data/processed/clean_final_data.csv"
# Load the CSV file into a DataFrame
df = pd.read_csv(file_path)
# Display the first few rows of the DataFrame to verify its content
df.head()
# Out:
#                District Lower layer super output area            Ward  \
# 0  Barking and Dagenham     Barking and Dagenham 001A  Chadwell Heath
# 1  Barking and Dagenham     Barking and Dagenham 001A  Chadwell Heath
# 2  Barking and Dagenham     Barking and Dagenham 001A  Chadwell Heath
# 3  Barking and Dagenham     Barking and Dagenham 001A  Chadwell Heath
# 4  Barking and Dagenham     Barking and Dagenham 001A  Chadwell Heath
#
#   Postcode Postcode district  London zone   Latitude  Longitude  \
# 0  RM6 5PU               RM6            5  51.587985   0.134785
# 1  RM6 5LJ               RM6            5  51.584118   0.137387
# 2  RM6 5QJ               RM6            5  51.588871   0.140933
# 3  RM6 5NB               RM6            5  51.586918   0.133147
# 4  RM6 5ND               RM6            5  51.587073   0.131523
#
#    Average Income  Total Crimes  Index of Multiple Deprivation  \
# 0           43600           334                           5097
# 1           43600           334                           5097
# 2           43600           334                           5097
# 3           43600           334                           5097
# 4           43600           334                           5097
#
#                Rural/urban  Average Rent Price  Budget-Friendly Rent Price  \
# 0  Urban major conurbation         1226.333333                 1095.833333
# 1  Urban major conurbation         1226.333333                 1095.833333
# 2  Urban major conurbation         1226.333333                 1095.833333
# 3  Urban major conurbation         1226.333333                 1095.833333
# 4  Urban major conurbation         1226.333333                 1095.833333
#
#         Median  Premium Rents Price  Mean average price  \
# 0  1202.833333          1376.666667           355457.75
# 1  1202.833333          1376.666667           355457.75
# 2  1202.833333          1376.666667           355457.75
# 3  1202.833333          1376.666667           355457.75
# 4  1202.833333          1376.666667           355457.75
#
#    Annual mean average flat price  Annual mean average terraced price  \
# 0                       359436.75                            235446.5
# 1                       359436.75                            235446.5
# 2                       359436.75                            235446.5
# 3                       359436.75                            235446.5
# 4                       359436.75                            235446.5
#
#    Annual mean average semi price  Annual mean average detached price  \
# 0                        393380.0                           444454.25
# 1                        393380.0                           444454.25
# 2                        393380.0                           444454.25
# 3                        393380.0                           444454.25
# 4                        393380.0                           444454.25
#
#    Agriculture, Forestry & Fishing  Manufacturing & Production  \
# 0                             15.0                       325.0
# 1                             15.0                       325.0
# 2                             15.0                       325.0
# 3                             15.0                       325.0
# 4                             15.0                       325.0
#
#    Building & Construction  Automotive Services  Grocery stores & Wholesale  \
# 0                   1965.0                270.0                       385.0
# 1                   1965.0                270.0                       385.0
# 2                   1965.0                270.0                       385.0
# 3                   1965.0                270.0                       385.0
# 4                   1965.0                270.0                       385.0
#
#    Shops & Retail  Transportation & Storage  Hotels & Restaurants  \
# 0           775.0                     760.0                 380.0
# 1           775.0                     760.0                 380.0
# 2           775.0                     760.0                 380.0
# 3           775.0                     760.0                 380.0
# 4           775.0                     760.0                 380.0
#
#    Tech & Communication  Finance & Insurance  Real Estate Services  \
# 0                 465.0                 60.0                 175.0
# 1                 465.0                 60.0                 175.0
# 2                 465.0                 60.0                 175.0
# 3                 465.0                 60.0                 175.0
# 4                 465.0                 60.0                 175.0
#
#    Professional, Scientific & Technical  \
# 0                                 725.0
# 1                                 725.0
# 2                                 725.0
# 3                                 725.0
# 4                                 725.0
#
#    Business Administration & Support Services  Public Sector & Defence  \
# 0                                       770.0                      0.0
# 1                                       770.0                      0.0
# 2                                       770.0                      0.0
# 3                                       770.0                      0.0
# 4                                       770.0                      0.0
#
#    Education  Healthcare Services  \
# 0      130.0                340.0
# 1      130.0                340.0
# 2      130.0                340.0
# 3      130.0                340.0
# 4      130.0                340.0
#
#    Arts, Entertainment, Recreation & Other Services  Total parks in District  \
# 0                                             345.0                       73
# 1                                             345.0                       73
# 2                                             345.0                       73
# 3                                             345.0                       73
# 4                                             345.0                       73
#
#    Majority_Christian  Majority_Hindu  Majority_Jewish  \
# 0                True           False            False
# 1                True           False            False
# 2                True           False            False
# 3                True           False            False
# 4                True           False            False
#
#    Majority_Muslim (Islam)  Majority_No religion  \
# 0                    False                 False
# 1                    False                 False
# 2                    False                 False
# 3                    False                 False
# 4                    False                 False
#
#    Majority_Religion not stated  Majority_Sikh  Second_Christian  \
# 0                         False          False             False
# 1                         False          False             False
# 2                         False          False             False
# 3                         False          False             False
# 4                         False          False             False
#
#    Second_Hindu  Second_Jewish  Second_Muslim (Islam)  Second_No religion  \
# 0         False          False                  False                True
# 1         False          False                  False                True
# 2         False          False                  False                True
# 3         False          False                  False                True
# 4         False          False                  False                True
#
#    Second_Religion not stated  Second_Sikh  Third_Christian  Third_Hindu  \
# 0                       False        False            False        False
# 1                       False        False            False        False
# 2                       False        False            False        False
# 3                       False        False            False        False
# 4                       False        False            False        False
#
#    Third_Jewish  Third_Muslim (Islam)  Third_No religion  \
# 0         False                 False              False
# 1         False                 False              False
# 2         False                 False              False
# 3         False                 False              False
# 4         False                 False              False
#
#    Third_Other religion  Third_Religion not stated  Third_Sikh  \
# 0                 False                       True       False
# 1                 False                       True       False
# 2                 False                       True       False
# 3                 False                       True       False
# 4                 False                       True       False
#
#    Majority_African  Majority_Any other ethnic group  Majority_Arab  \
# 0             False                            False          False
# 1             False                            False          False
# 2             False                            False          False
# 3             False                            False          False
# 4             False                            False          False
#
#    Majority_Australian/New Zealander  \
# 0                              False
# 1                              False
# 2                              False
# 3                              False
# 4                              False
#
#    Majority_Bangladeshi, British Bangladeshi  Majority_Caribbean  \
# 0                                      False                True
# 1                                      False                True
# 2                                      False                True
# 3                                      False                True
# 4                                      False                True
#
#    Majority_Chinese  Majority_Greek  Majority_Indian or British Indian  \
# 0             False           False                              False
# 1             False           False                              False
# 2             False           False                              False
# 3             False           False                              False
# 4             False           False                              False
#
#    Majority_Irish  Majority_Korean  Majority_Other Western European  \
# 0           False            False                            False
# 1           False            False                            False
# 2           False            False                            False
# 3           False            False                            False
# 4           False            False                            False
#
#    Majority_Pakistani or British Pakistani  Majority_Sri Lankan  \
# 0                                    False                False
# 1                                    False                False
# 2                                    False                False
# 3                                    False                False
# 4                                    False                False
#
#    Majority_Turkish  Majority_White and Asian  Second_Afghan  Second_African  \
# 0             False                     False          False            True
# 1             False                     False          False            True
# 2             False                     False          False            True
# 3             False                     False          False            True
# 4             False                     False          False            True
#
#    Second_Any other ethnic group  Second_Arab  \
# 0                          False        False
# 1                          False        False
# 2                          False        False
# 3                          False        False
# 4                          False        False
#
#    Second_Australian/New Zealander  Second_Bangladeshi, British Bangladeshi  \
# 0                            False                                    False
# 1                            False                                    False
# 2                            False                                    False
# 3                            False                                    False
# 4                            False                                    False
#
#    Second_Black British  Second_Caribbean  Second_Chinese  \
# 0                 False             False           False
# 1                 False             False           False
# 2                 False             False           False
# 3                 False             False           False
# 4                 False             False           False
#
#    Second_English/Welsh/Scottish/Northern Irish/British  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Second_European Mixed  Second_Filipino  Second_Greek  Second_Greek Cypriot  \
# 0                  False            False         False                 False
# 1                  False            False         False                 False
# 2                  False            False         False                 False
# 3                  False            False         False                 False
# 4                  False            False         False                 False
#
#    Second_Indian or British Indian  Second_Irish  Second_Japanese  \
# 0                            False         False            False
# 1                            False         False            False
# 2                            False         False            False
# 3                            False         False            False
# 4                            False         False            False
#
#    Second_Korean  Second_North American  Second_Other Western European  \
# 0          False                  False                          False
# 1          False                  False                          False
# 2          False                  False                          False
# 3          False                  False                          False
# 4          False                  False                          False
#
#    Second_Pakistani or British Pakistani  Second_Sri Lankan  Second_Turkish  \
# 0                                  False              False           False
# 1                                  False              False           False
# 2                                  False              False           False
# 3                                  False              False           False
# 4                                  False              False           False
#
#    Second_White and Black Caribbean  Third_African  \
# 0                             False          False
# 1                             False          False
# 2                             False          False
# 3                             False          False
# 4                             False          False
#
#    Third_Any other ethnic group  Third_Arab  Third_Australian/New Zealander  \
# 0                         False       False                           False
# 1                         False       False                           False
# 2                         False       False                           False
# 3                         False       False                           False
# 4                         False       False                           False
#
#    Third_Bangladeshi, British Bangladeshi  Third_Black British  \
# 0                                   False                 True
# 1                                   False                 True
# 2                                   False                 True
# 3                                   False                 True
# 4                                   False                 True
#
#    Third_Caribbean  Third_Chinese  \
# 0            False          False
# 1            False          False
# 2            False          False
# 3            False          False
# 4            False          False
#
#    Third_English/Welsh/Scottish/Northern Irish/British  Third_European Mixed  \
# 0                                              False                   False
# 1                                              False                   False
# 2                                              False                   False
# 3                                              False                   False
# 4                                              False                   False
#
#    Third_Greek  Third_Greek Cypriot  Third_Indian or British Indian  \
# 0        False                False                           False
# 1        False                False                           False
# 2        False                False                           False
# 3        False                False                           False
# 4        False                False                           False
#
#    Third_Irish  Third_Japanese  Third_Korean  Third_North American  \
# 0        False           False         False                 False
# 1        False           False         False                 False
# 2        False           False         False                 False
# 3        False           False         False                 False
# 4        False           False         False                 False
#
#    Third_Other Western European  Third_Pakistani or British Pakistani  \
# 0                         False                                 False
# 1                         False                                 False
# 2                         False                                 False
# 3                         False                                 False
# 4                         False                                 False
#
#    Third_Polish  Third_Sri Lankan  Third_Turkish  Third_White and Asian  \
# 0         False             False          False                  False
# 1         False             False          False                  False
# 2         False             False          False                  False
# 3         False             False          False                  False
# 4         False             False          False                  False
#
#    Third_White and Black Caribbean
# 0                            False
# 1                            False
# 2                            False
# 3                            False
# 4                            False

# %%
# Create a subset by dropping specific columns
columns_to_drop = [
    "District",    
    "Lower layer super output area",    
    "Ward",    
    "Postcode",    
    "Postcode district",    
    "London zone",    
    "Latitude",    
    "Longitude",
    "Rural/urban"
]

# Dropping the specified columns
dfSubset = df.drop(columns=columns_to_drop)

# Displaying the first few rows of the subset DataFrame to verify its content
dfSubset.head()
# Out:
#    Average Income  Total Crimes  Index of Multiple Deprivation  \
# 0           43600           334                           5097
# 1           43600           334                           5097
# 2           43600           334                           5097
# 3           43600           334                           5097
# 4           43600           334                           5097
#
#    Average Rent Price  Budget-Friendly Rent Price       Median  \
# 0         1226.333333                 1095.833333  1202.833333
# 1         1226.333333                 1095.833333  1202.833333
# 2         1226.333333                 1095.833333  1202.833333
# 3         1226.333333                 1095.833333  1202.833333
# 4         1226.333333                 1095.833333  1202.833333
#
#    Premium Rents Price  Mean average price  Annual mean average flat price  \
# 0          1376.666667           355457.75                       359436.75
# 1          1376.666667           355457.75                       359436.75
# 2          1376.666667           355457.75                       359436.75
# 3          1376.666667           355457.75                       359436.75
# 4          1376.666667           355457.75                       359436.75
#
#    Annual mean average terraced price  Annual mean average semi price  \
# 0                            235446.5                        393380.0
# 1                            235446.5                        393380.0
# 2                            235446.5                        393380.0
# 3                            235446.5                        393380.0
# 4                            235446.5                        393380.0
#
#    Annual mean average detached price  Agriculture, Forestry & Fishing  \
# 0                           444454.25                             15.0
# 1                           444454.25                             15.0
# 2                           444454.25                             15.0
# 3                           444454.25                             15.0
# 4                           444454.25                             15.0
#
#    Manufacturing & Production  Building & Construction  Automotive Services  \
# 0                       325.0                   1965.0                270.0
# 1                       325.0                   1965.0                270.0
# 2                       325.0                   1965.0                270.0
# 3                       325.0                   1965.0                270.0
# 4                       325.0                   1965.0                270.0
#
#    Grocery stores & Wholesale  Shops & Retail  Transportation & Storage  \
# 0                       385.0           775.0                     760.0
# 1                       385.0           775.0                     760.0
# 2                       385.0           775.0                     760.0
# 3                       385.0           775.0                     760.0
# 4                       385.0           775.0                     760.0
#
#    Hotels & Restaurants  Tech & Communication  Finance & Insurance  \
# 0                 380.0                 465.0                 60.0
# 1                 380.0                 465.0                 60.0
# 2                 380.0                 465.0                 60.0
# 3                 380.0                 465.0                 60.0
# 4                 380.0                 465.0                 60.0
#
#    Real Estate Services  Professional, Scientific & Technical  \
# 0                 175.0                                 725.0
# 1                 175.0                                 725.0
# 2                 175.0                                 725.0
# 3                 175.0                                 725.0
# 4                 175.0                                 725.0
#
#    Business Administration & Support Services  Public Sector & Defence  \
# 0                                       770.0                      0.0
# 1                                       770.0                      0.0
# 2                                       770.0                      0.0
# 3                                       770.0                      0.0
# 4                                       770.0                      0.0
#
#    Education  Healthcare Services  \
# 0      130.0                340.0
# 1      130.0                340.0
# 2      130.0                340.0
# 3      130.0                340.0
# 4      130.0                340.0
#
#    Arts, Entertainment, Recreation & Other Services  Total parks in District  \
# 0                                             345.0                       73
# 1                                             345.0                       73
# 2                                             345.0                       73
# 3                                             345.0                       73
# 4                                             345.0                       73
#
#    Majority_Christian  Majority_Hindu  Majority_Jewish  \
# 0                True           False            False
# 1                True           False            False
# 2                True           False            False
# 3                True           False            False
# 4                True           False            False
#
#    Majority_Muslim (Islam)  Majority_No religion  \
# 0                    False                 False
# 1                    False                 False
# 2                    False                 False
# 3                    False                 False
# 4                    False                 False
#
#    Majority_Religion not stated  Majority_Sikh  Second_Christian  \
# 0                         False          False             False
# 1                         False          False             False
# 2                         False          False             False
# 3                         False          False             False
# 4                         False          False             False
#
#    Second_Hindu  Second_Jewish  Second_Muslim (Islam)  Second_No religion  \
# 0         False          False                  False                True
# 1         False          False                  False                True
# 2         False          False                  False                True
# 3         False          False                  False                True
# 4         False          False                  False                True
#
#    Second_Religion not stated  Second_Sikh  Third_Christian  Third_Hindu  \
# 0                       False        False            False        False
# 1                       False        False            False        False
# 2                       False        False            False        False
# 3                       False        False            False        False
# 4                       False        False            False        False
#
#    Third_Jewish  Third_Muslim (Islam)  Third_No religion  \
# 0         False                 False              False
# 1         False                 False              False
# 2         False                 False              False
# 3         False                 False              False
# 4         False                 False              False
#
#    Third_Other religion  Third_Religion not stated  Third_Sikh  \
# 0                 False                       True       False
# 1                 False                       True       False
# 2                 False                       True       False
# 3                 False                       True       False
# 4                 False                       True       False
#
#    Majority_African  Majority_Any other ethnic group  Majority_Arab  \
# 0             False                            False          False
# 1             False                            False          False
# 2             False                            False          False
# 3             False                            False          False
# 4             False                            False          False
#
#    Majority_Australian/New Zealander  \
# 0                              False
# 1                              False
# 2                              False
# 3                              False
# 4                              False
#
#    Majority_Bangladeshi, British Bangladeshi  Majority_Caribbean  \
# 0                                      False                True
# 1                                      False                True
# 2                                      False                True
# 3                                      False                True
# 4                                      False                True
#
#    Majority_Chinese  Majority_Greek  Majority_Indian or British Indian  \
# 0             False           False                              False
# 1             False           False                              False
# 2             False           False                              False
# 3             False           False                              False
# 4             False           False                              False
#
#    Majority_Irish  Majority_Korean  Majority_Other Western European  \
# 0           False            False                            False
# 1           False            False                            False
# 2           False            False                            False
# 3           False            False                            False
# 4           False            False                            False
#
#    Majority_Pakistani or British Pakistani  Majority_Sri Lankan  \
# 0                                    False                False
# 1                                    False                False
# 2                                    False                False
# 3                                    False                False
# 4                                    False                False
#
#    Majority_Turkish  Majority_White and Asian  Second_Afghan  Second_African  \
# 0             False                     False          False            True
# 1             False                     False          False            True
# 2             False                     False          False            True
# 3             False                     False          False            True
# 4             False                     False          False            True
#
#    Second_Any other ethnic group  Second_Arab  \
# 0                          False        False
# 1                          False        False
# 2                          False        False
# 3                          False        False
# 4                          False        False
#
#    Second_Australian/New Zealander  Second_Bangladeshi, British Bangladeshi  \
# 0                            False                                    False
# 1                            False                                    False
# 2                            False                                    False
# 3                            False                                    False
# 4                            False                                    False
#
#    Second_Black British  Second_Caribbean  Second_Chinese  \
# 0                 False             False           False
# 1                 False             False           False
# 2                 False             False           False
# 3                 False             False           False
# 4                 False             False           False
#
#    Second_English/Welsh/Scottish/Northern Irish/British  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Second_European Mixed  Second_Filipino  Second_Greek  Second_Greek Cypriot  \
# 0                  False            False         False                 False
# 1                  False            False         False                 False
# 2                  False            False         False                 False
# 3                  False            False         False                 False
# 4                  False            False         False                 False
#
#    Second_Indian or British Indian  Second_Irish  Second_Japanese  \
# 0                            False         False            False
# 1                            False         False            False
# 2                            False         False            False
# 3                            False         False            False
# 4                            False         False            False
#
#    Second_Korean  Second_North American  Second_Other Western European  \
# 0          False                  False                          False
# 1          False                  False                          False
# 2          False                  False                          False
# 3          False                  False                          False
# 4          False                  False                          False
#
#    Second_Pakistani or British Pakistani  Second_Sri Lankan  Second_Turkish  \
# 0                                  False              False           False
# 1                                  False              False           False
# 2                                  False              False           False
# 3                                  False              False           False
# 4                                  False              False           False
#
#    Second_White and Black Caribbean  Third_African  \
# 0                             False          False
# 1                             False          False
# 2                             False          False
# 3                             False          False
# 4                             False          False
#
#    Third_Any other ethnic group  Third_Arab  Third_Australian/New Zealander  \
# 0                         False       False                           False
# 1                         False       False                           False
# 2                         False       False                           False
# 3                         False       False                           False
# 4                         False       False                           False
#
#    Third_Bangladeshi, British Bangladeshi  Third_Black British  \
# 0                                   False                 True
# 1                                   False                 True
# 2                                   False                 True
# 3                                   False                 True
# 4                                   False                 True
#
#    Third_Caribbean  Third_Chinese  \
# 0            False          False
# 1            False          False
# 2            False          False
# 3            False          False
# 4            False          False
#
#    Third_English/Welsh/Scottish/Northern Irish/British  Third_European Mixed  \
# 0                                              False                   False
# 1                                              False                   False
# 2                                              False                   False
# 3                                              False                   False
# 4                                              False                   False
#
#    Third_Greek  Third_Greek Cypriot  Third_Indian or British Indian  \
# 0        False                False                           False
# 1        False                False                           False
# 2        False                False                           False
# 3        False                False                           False
# 4        False                False                           False
#
#    Third_Irish  Third_Japanese  Third_Korean  Third_North American  \
# 0        False           False         False                 False
# 1        False           False         False                 False
# 2        False           False         False                 False
# 3        False           False         False                 False
# 4        False           False         False                 False
#
#    Third_Other Western European  Third_Pakistani or British Pakistani  \
# 0                         False                                 False
# 1                         False                                 False
# 2                         False                                 False
# 3                         False                                 False
# 4                         False                                 False
#
#    Third_Polish  Third_Sri Lankan  Third_Turkish  Third_White and Asian  \
# 0         False             False          False                  False
# 1         False             False          False                  False
# 2         False             False          False                  False
# 3         False             False          False                  False
# 4         False             False          False                  False
#
#    Third_White and Black Caribbean
# 0                            False
# 1                            False
# 2                            False
# 3                            False
# 4                            False

# %%
# Checking data types to convert to numerical values
dfSubset.dtypes
# Out:
# Average Income                                            int64
# Total Crimes                                              int64
# Index of Multiple Deprivation                             int64
# Average Rent Price                                      float64
# Budget-Friendly Rent Price                              float64
# Median                                                  float64
# Premium Rents Price                                     float64
# Mean average price                                      float64
# Annual mean average flat price                          float64
# Annual mean average terraced price                      float64
# Annual mean average semi price                          float64
# Annual mean average detached price                      float64
# Agriculture, Forestry & Fishing                         float64
# Manufacturing & Production                              float64
# Building & Construction                                 float64
# Automotive Services                                     float64
# Grocery stores & Wholesale                              float64
# Shops & Retail                                          float64
# Transportation & Storage                                float64
# Hotels & Restaurants                                    float64
# Tech & Communication                                    float64
# Finance & Insurance                                     float64
# Real Estate Services                                    float64
# Professional, Scientific & Technical                    float64
# Business Administration & Support Services              float64
# Public Sector & Defence                                 float64
# Education                                               float64
# Healthcare Services                                     float64
# Arts, Entertainment, Recreation & Other Services        float64
# Total parks in District                                   int64
# Majority_Christian                                         bool
# Majority_Hindu                                             bool
# Majority_Jewish                                            bool
# Majority_Muslim (Islam)                                    bool
# Majority_No religion                                       bool
# Majority_Religion not stated                               bool
# Majority_Sikh                                              bool
# Second_Christian                                           bool
# Second_Hindu                                               bool
# Second_Jewish                                              bool
# Second_Muslim (Islam)                                      bool
# Second_No religion                                         bool
# Second_Religion not stated                                 bool
# Second_Sikh                                                bool
# Third_Christian                                            bool
# Third_Hindu                                                bool
# Third_Jewish                                               bool
# Third_Muslim (Islam)                                       bool
# Third_No religion                                          bool
# Third_Other religion                                       bool
# Third_Religion not stated                                  bool
# Third_Sikh                                                 bool
# Majority_African                                           bool
# Majority_Any other ethnic group                            bool
# Majority_Arab                                              bool
# Majority_Australian/New Zealander                          bool
# Majority_Bangladeshi, British Bangladeshi                  bool
# Majority_Caribbean                                         bool
# Majority_Chinese                                           bool
# Majority_Greek                                             bool
# Majority_Indian or British Indian                          bool
# Majority_Irish                                             bool
# Majority_Korean                                            bool
# Majority_Other Western European                            bool
# Majority_Pakistani or British Pakistani                    bool
# Majority_Sri Lankan                                        bool
# Majority_Turkish                                           bool
# Majority_White and Asian                                   bool
# Second_Afghan                                              bool
# Second_African                                             bool
# Second_Any other ethnic group                              bool
# Second_Arab                                                bool
# Second_Australian/New Zealander                            bool
# Second_Bangladeshi, British Bangladeshi                    bool
# Second_Black British                                       bool
# Second_Caribbean                                           bool
# Second_Chinese                                             bool
# Second_English/Welsh/Scottish/Northern Irish/British       bool
# Second_European Mixed                                      bool
# Second_Filipino                                            bool
# Second_Greek                                               bool
# Second_Greek Cypriot                                       bool
# Second_Indian or British Indian                            bool
# Second_Irish                                               bool
# Second_Japanese                                            bool
# Second_Korean                                              bool
# Second_North American                                      bool
# Second_Other Western European                              bool
# Second_Pakistani or British Pakistani                      bool
# Second_Sri Lankan                                          bool
# Second_Turkish                                             bool
# Second_White and Black Caribbean                           bool
# Third_African                                              bool
# Third_Any other ethnic group                               bool
# Third_Arab                                                 bool
# Third_Australian/New Zealander                             bool
# Third_Bangladeshi, British Bangladeshi                     bool
# Third_Black British                                        bool
# Third_Caribbean                                            bool
# Third_Chinese                                              bool
# Third_English/Welsh/Scottish/Northern Irish/British        bool
# Third_European Mixed                                       bool
# Third_Greek                                                bool
# Third_Greek Cypriot                                        bool
# Third_Indian or British Indian                             bool
# Third_Irish                                                bool
# Third_Japanese                                             bool
# Third_Korean                                               bool
# Third_North American                                       bool
# Third_Other Western European                               bool
# Third_Pakistani or British Pakistani                       bool
# Third_Polish                                               bool
# Third_Sri Lankan                                           bool
# Third_Turkish                                              bool
# Third_White and Asian                                      bool
# Third_White and Black Caribbean                            bool
# dtype: object

# %%
# List of boolean columns
bool_columns = [
    "Majority_Christian", "Majority_Hindu", "Majority_Jewish", "Majority_Muslim (Islam)",
    "Majority_No religion", "Majority_Religion not stated", "Majority_Sikh", "Second_Christian",
    "Second_Hindu", "Second_Jewish", "Second_Muslim (Islam)", "Second_No religion",
    "Second_Religion not stated", "Second_Sikh", "Third_Christian", "Third_Hindu",
    "Third_Jewish", "Third_Muslim (Islam)", "Third_No religion", "Third_Other religion",
    "Third_Religion not stated", "Third_Sikh", "Majority_African", "Majority_Any other ethnic group",
    "Majority_Arab", "Majority_Australian/New Zealander", "Majority_Bangladeshi, British Bangladeshi",
    "Majority_Caribbean", "Majority_Chinese", "Majority_Greek", "Majority_Indian or British Indian",
    "Majority_Irish", "Majority_Korean", "Majority_Other Western European", "Majority_Pakistani or British Pakistani",
    "Majority_Sri Lankan", "Majority_Turkish", "Majority_White and Asian", "Second_Afghan",
    "Second_African", "Second_Any other ethnic group", "Second_Arab", "Second_Australian/New Zealander",
    "Second_Bangladeshi, British Bangladeshi", "Second_Black British", "Second_Caribbean",
    "Second_Chinese", "Second_English/Welsh/Scottish/Northern Irish/British", "Second_European Mixed",
    "Second_Filipino", "Second_Greek", "Second_Greek Cypriot", "Second_Indian or British Indian",
    "Second_Irish", "Second_Japanese", "Second_Korean", "Second_North American", "Second_Other Western European",
    "Second_Pakistani or British Pakistani", "Second_Sri Lankan", "Second_Turkish", "Second_White and Black Caribbean",
    "Third_African", "Third_Any other ethnic group", "Third_Arab", "Third_Australian/New Zealander",
    "Third_Bangladeshi, British Bangladeshi", "Third_Black British", "Third_Caribbean", "Third_Chinese",
    "Third_English/Welsh/Scottish/Northern Irish/British", "Third_European Mixed", "Third_Greek",
    "Third_Greek Cypriot", "Third_Indian or British Indian", "Third_Irish", "Third_Japanese",
    "Third_Korean", "Third_North American", "Third_Other Western European", "Third_Pakistani or British Pakistani",
    "Third_Polish", "Third_Sri Lankan", "Third_Turkish", "Third_White and Asian", "Third_White and Black Caribbean"
]

# Convert boolean columns to int
for column in bool_columns:
    dfSubset[column] = dfSubset[column].astype(int)
    
# Checking data types of the converted features 
dfSubset.dtypes
# Out:
# Average Income                                            int64
# Total Crimes                                              int64
# Index of Multiple Deprivation                             int64
# Average Rent Price                                      float64
# Budget-Friendly Rent Price                              float64
# Median                                                  float64
# Premium Rents Price                                     float64
# Mean average price                                      float64
# Annual mean average flat price                          float64
# Annual mean average terraced price                      float64
# Annual mean average semi price                          float64
# Annual mean average detached price                      float64
# Agriculture, Forestry & Fishing                         float64
# Manufacturing & Production                              float64
# Building & Construction                                 float64
# Automotive Services                                     float64
# Grocery stores & Wholesale                              float64
# Shops & Retail                                          float64
# Transportation & Storage                                float64
# Hotels & Restaurants                                    float64
# Tech & Communication                                    float64
# Finance & Insurance                                     float64
# Real Estate Services                                    float64
# Professional, Scientific & Technical                    float64
# Business Administration & Support Services              float64
# Public Sector & Defence                                 float64
# Education                                               float64
# Healthcare Services                                     float64
# Arts, Entertainment, Recreation & Other Services        float64
# Total parks in District                                   int64
# Majority_Christian                                        int64
# Majority_Hindu                                            int64
# Majority_Jewish                                           int64
# Majority_Muslim (Islam)                                   int64
# Majority_No religion                                      int64
# Majority_Religion not stated                              int64
# Majority_Sikh                                             int64
# Second_Christian                                          int64
# Second_Hindu                                              int64
# Second_Jewish                                             int64
# Second_Muslim (Islam)                                     int64
# Second_No religion                                        int64
# Second_Religion not stated                                int64
# Second_Sikh                                               int64
# Third_Christian                                           int64
# Third_Hindu                                               int64
# Third_Jewish                                              int64
# Third_Muslim (Islam)                                      int64
# Third_No religion                                         int64
# Third_Other religion                                      int64
# Third_Religion not stated                                 int64
# Third_Sikh                                                int64
# Majority_African                                          int64
# Majority_Any other ethnic group                           int64
# Majority_Arab                                             int64
# Majority_Australian/New Zealander                         int64
# Majority_Bangladeshi, British Bangladeshi                 int64
# Majority_Caribbean                                        int64
# Majority_Chinese                                          int64
# Majority_Greek                                            int64
# Majority_Indian or British Indian                         int64
# Majority_Irish                                            int64
# Majority_Korean                                           int64
# Majority_Other Western European                           int64
# Majority_Pakistani or British Pakistani                   int64
# Majority_Sri Lankan                                       int64
# Majority_Turkish                                          int64
# Majority_White and Asian                                  int64
# Second_Afghan                                             int64
# Second_African                                            int64
# Second_Any other ethnic group                             int64
# Second_Arab                                               int64
# Second_Australian/New Zealander                           int64
# Second_Bangladeshi, British Bangladeshi                   int64
# Second_Black British                                      int64
# Second_Caribbean                                          int64
# Second_Chinese                                            int64
# Second_English/Welsh/Scottish/Northern Irish/British      int64
# Second_European Mixed                                     int64
# Second_Filipino                                           int64
# Second_Greek                                              int64
# Second_Greek Cypriot                                      int64
# Second_Indian or British Indian                           int64
# Second_Irish                                              int64
# Second_Japanese                                           int64
# Second_Korean                                             int64
# Second_North American                                     int64
# Second_Other Western European                             int64
# Second_Pakistani or British Pakistani                     int64
# Second_Sri Lankan                                         int64
# Second_Turkish                                            int64
# Second_White and Black Caribbean                          int64
# Third_African                                             int64
# Third_Any other ethnic group                              int64
# Third_Arab                                                int64
# Third_Australian/New Zealander                            int64
# Third_Bangladeshi, British Bangladeshi                    int64
# Third_Black British                                       int64
# Third_Caribbean                                           int64
# Third_Chinese                                             int64
# Third_English/Welsh/Scottish/Northern Irish/British       int64
# Third_European Mixed                                      int64
# Third_Greek                                               int64
# Third_Greek Cypriot                                       int64
# Third_Indian or British Indian                            int64
# Third_Irish                                               int64
# Third_Japanese                                            int64
# Third_Korean                                              int64
# Third_North American                                      int64
# Third_Other Western European                              int64
# Third_Pakistani or British Pakistani                      int64
# Third_Polish                                              int64
# Third_Sri Lankan                                          int64
# Third_Turkish                                             int64
# Third_White and Asian                                     int64
# Third_White and Black Caribbean                           int64
# dtype: object

# %%
# Create an instance of the StandardScaler
scaler = StandardScaler()
# Apply the scaler to the entire dfSubset (as all features are now numerical)
dfSubset_scaled = scaler.fit_transform(dfSubset)
# Convert the scaled array back to a DataFrame, using the same column names
dfSubset_scaled_df = pd.DataFrame(dfSubset_scaled, columns=dfSubset.columns)
# This is your final scaled DataFrame ready for clustering
dfSubset_final = dfSubset_scaled_df
# Display the first few rows to verify the scaled data
dfSubset_final.head()
# Out:
#    Average Income  Total Crimes  Index of Multiple Deprivation  \
# 0        -1.45114     -0.165134                      -1.332421
# 1        -1.45114     -0.165134                      -1.332421
# 2        -1.45114     -0.165134                      -1.332421
# 3        -1.45114     -0.165134                      -1.332421
# 4        -1.45114     -0.165134                      -1.332421
#
#    Average Rent Price  Budget-Friendly Rent Price    Median  \
# 0           -1.100179                   -1.092846 -1.094383
# 1           -1.100179                   -1.092846 -1.094383
# 2           -1.100179                   -1.092846 -1.094383
# 3           -1.100179                   -1.092846 -1.094383
# 4           -1.100179                   -1.092846 -1.094383
#
#    Premium Rents Price  Mean average price  Annual mean average flat price  \
# 0            -1.032512           -0.889703                       -0.830193
# 1            -1.032512           -0.889703                       -0.830193
# 2            -1.032512           -0.889703                       -0.830193
# 3            -1.032512           -0.889703                       -0.830193
# 4            -1.032512           -0.889703                       -0.830193
#
#    Annual mean average terraced price  Annual mean average semi price  \
# 0                            -0.69746                       -0.609429
# 1                            -0.69746                       -0.609429
# 2                            -0.69746                       -0.609429
# 3                            -0.69746                       -0.609429
# 4                            -0.69746                       -0.609429
#
#    Annual mean average detached price  Agriculture, Forestry & Fishing  \
# 0                           -0.573845                        -0.631506
# 1                           -0.573845                        -0.631506
# 2                           -0.573845                        -0.631506
# 3                           -0.573845                        -0.631506
# 4                           -0.573845                        -0.631506
#
#    Manufacturing & Production  Building & Construction  Automotive Services  \
# 0                   -0.838932                -0.047401             0.333238
# 1                   -0.838932                -0.047401             0.333238
# 2                   -0.838932                -0.047401             0.333238
# 3                   -0.838932                -0.047401             0.333238
# 4                   -0.838932                -0.047401             0.333238
#
#    Grocery stores & Wholesale  Shops & Retail  Transportation & Storage  \
# 0                   -0.816982       -0.937495                  0.924932
# 1                   -0.816982       -0.937495                  0.924932
# 2                   -0.816982       -0.937495                  0.924932
# 3                   -0.816982       -0.937495                  0.924932
# 4                   -0.816982       -0.937495                  0.924932
#
#    Hotels & Restaurants  Tech & Communication  Finance & Insurance  \
# 0              -1.05654             -1.109139            -0.462257
# 1              -1.05654             -1.109139            -0.462257
# 2              -1.05654             -1.109139            -0.462257
# 3              -1.05654             -1.109139            -0.462257
# 4              -1.05654             -1.109139            -0.462257
#
#    Real Estate Services  Professional, Scientific & Technical  \
# 0              -0.73738                             -1.001387
# 1              -0.73738                             -1.001387
# 2              -0.73738                             -1.001387
# 3              -0.73738                             -1.001387
# 4              -0.73738                             -1.001387
#
#    Business Administration & Support Services  Public Sector & Defence  \
# 0                                    -0.78883                -0.505935
# 1                                    -0.78883                -0.505935
# 2                                    -0.78883                -0.505935
# 3                                    -0.78883                -0.505935
# 4     -0.061729         -0.056812      -0.042299              -0.041704
#
#    Third_White and Black Caribbean
# 0                        -0.026409
# 1                        -0.026409
# 2                        -0.026409
# 3                        -0.026409
# 4                        -0.026409

# %%
# Checking the df shape
dfSubset_final.shape
# Out:
# (160695, 116)

# %%
# Double checking the features are ready for clustering
dfSubset_final.dtypes
# Out:
# Average Income                                          float64
# Total Crimes                                            float64
# Index of Multiple Deprivation                           float64
# Average Rent Price                                      float64
# Budget-Friendly Rent Price                              float64
# Median                                                  float64
# Premium Rents Price                                     float64
# Mean average price                                      float64
# Annual mean average flat price                          float64
# Annual mean average terraced price                      float64
# Annual mean average semi price                          float64
# Annual mean average detached price                      float64
# Agriculture, Forestry & Fishing                         float64
# Manufacturing & Production                              float64
# Building & Construction                                 float64
# Automotive Services                                     float64
# Grocery stores & Wholesale                              float64
# Shops & Retail                                          float64
# Transportation & Storage                                float64
# Hotels & Restaurants                                    float64
# Tech & Communication                                    float64
# Finance & Insurance                                     float64
# Real Estate Services                                    float64
# Professional, Scientific & Technical                    float64
# Business Administration & Support Services              float64
# Public Sector & Defence                                 float64
# Education                                               float64
# Healthcare Services                                     float64
# Arts, Entertainment, Recreation & Other Services        float64
# Total parks in District                                 float64
# Majority_Christian                                      float64
# Majority_Hindu                                          float64
# Majority_Jewish                                         float64
# Majority_Muslim (Islam)                                 float64
# Majority_No religion                                    float64
# Majority_Religion not stated                            float64
# Majority_Sikh                                           float64
# Second_Christian                                        float64
# Second_Hindu                                            float64
# Second_Jewish                                           float64
# Second_Muslim (Islam)                                   float64
# Second_No religion                                      float64
# Second_Religion not stated                              float64
# Second_Sikh                                             float64
# Third_Christian                                         float64
# Third_Hindu                                             float64
# Third_Jewish                                            float64
# Third_Muslim (Islam)                                    float64
# Third_No religion                                       float64
# Third_Other religion                                    float64
# Third_Religion not stated                               float64
# Third_Sikh                                              float64
# Majority_African                                        float64
# Majority_Any other ethnic group                         float64
# Majority_Arab                                           float64
# Majority_Australian/New Zealander                       float64
# Majority_Bangladeshi, British Bangladeshi               float64
# Majority_Caribbean                                      float64
# Majority_Chinese                                        float64
# Majority_Greek                                          float64
# Majority_Indian or British Indian                       float64
# Majority_Irish                                          float64
# Majority_Korean                                         float64
# Majority_Other Western European                         float64
# Majority_Pakistani or British Pakistani                 float64
# Majority_Sri Lankan                                     float64
# Majority_Turkish                                        float64
# Majority_White and Asian                                float64
# Second_Afghan                                           float64
# Second_African                                          float64
# Second_Any other ethnic group                           float64
# Second_Arab                                             float64
# Second_Australian/New Zealander                         float64
# Second_Bangladeshi, British Bangladeshi                 float64
# Second_Black British                                    float64
# Second_Caribbean                                        float64
# Second_Chinese                                          float64
# Second_English/Welsh/Scottish/Northern Irish/British    float64
# Second_European Mixed                                   float64
# Second_Filipino                                         float64
# Second_Greek                                            float64
# Second_Greek Cypriot                                    float64
# Second_Indian or British Indian                         float64
# Second_Irish                                            float64
# Second_Japanese                                         float64
# Second_Korean                                           float64
# Second_North American                                   float64
# Second_Other Western European                           float64
# Second_Pakistani or British Pakistani                   float64
# Second_Sri Lankan                                       float64
# Second_Turkish                                          float64
# Second_White and Black Caribbean                        float64
# Third_African                                           float64
# Third_Any other ethnic group                            float64
# Third_Arab                                              float64
# Third_Australian/New Zealander                          float64
# Third_Bangladeshi, British Bangladeshi                  float64
# Third_Black British                                     float64
# Third_Caribbean                                         float64
# Third_Chinese                                           float64
# Third_English/Welsh/Scottish/Northern Irish/British     float64
# Third_European Mixed                                    float64
# Third_Greek                                             float64
# Third_Greek Cypriot                                     float64
# Third_Indian or British Indian                          float64
# Third_Irish                                             float64
# Third_Japanese                                          float64
# Third_Korean                                            float64
# Third_North American                                    float64
# Third_Other Western European                            float64
# Third_Pakistani or British Pakistani                    float64
# Third_Polish                                            float64
# Third_Sri Lankan                                        float64
# Third_Turkish                                           float64
# Third_White and Asian                                   float64
# Third_White and Black Caribbean                         float64
# dtype: object

# %% [markdown]
# ### KMEANS

# %%
# Elbow method
inertia = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(dfSubset_final) # dfSubset_final
    inertia.append(kmeans.inertia_)

plt.figure(figsize=(10, 6))
plt.plot(range(1, 11), inertia, marker='o')
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()
# Out:
# /Users/alessandrosuarez_/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/alessandrosuarez_/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/alessandrosuarez_/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/alessandrosuarez_/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/alessandrosuarez_/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/alessandrosuarez_/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/alessandrosuarez_/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/alessandrosuarez_/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/alessandrosuarez_/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/alessandrosuarez_/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
# Silhouette Score
silhouette_scores = []
for k in range(2, 11):  # Silhouette score can't be computed for k=1
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(dfSubset_final) # dfSubset_final
    cluster_labels = kmeans.labels_
    silhouette_scores.append(silhouette_score(dfSubset_scaled, cluster_labels))

plt.figure(figsize=(10, 6))
plt.plot(range(2, 11), silhouette_scores, marker='o')
plt.title('Silhouette Score Method')
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette Score')
plt.show()
# Out:
# /Users/alessandrosuarez_/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/alessandrosuarez_/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/alessandrosuarez_/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/alessandrosuarez_/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/alessandrosuarez_/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/alessandrosuarez_/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/alessandrosuarez_/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/alessandrosuarez_/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/alessandrosuarez_/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
# David-Bouildin Index
db_scores = []
for k in range(2, 11):  # Can't compute for k=1
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(dfSubset_final) # dfSubset_final
    cluster_labels = kmeans.labels_
    db_scores.append(davies_bouldin_score(dfSubset_scaled, cluster_labels))

plt.figure(figsize=(10, 6))
plt.plot(range(2, 11), db_scores, marker='o')
plt.title('Davies–Bouldin Index')
plt.xlabel('Number of clusters')
plt.ylabel('Davies–Bouldin Index')
plt.show()
# Out:
# /Users/alessandrosuarez_/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/alessandrosuarez_/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/alessandrosuarez_/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/alessandrosuarez_/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/alessandrosuarez_/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/alessandrosuarez_/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/alessandrosuarez_/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/alessandrosuarez_/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/alessandrosuarez_/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
# Initialize KMeans with k clusters
kmeans = KMeans(n_clusters=5, random_state=42)

# Fit the model data
kmeans.fit(dfSubset_final) # dfSubset_final is the scaled dataset after standardization

# The labels_ attribute give the assigned cluster labels
cluster_labels = kmeans.labels_

# The cluster labels is a new column to DataFrame 
df['Cluster_Labels'] = cluster_labels

# To see the first few entries with their respective cluster assignments
df.head()
# Out:
# /Users/alessandrosuarez_/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#                District Lower layer super output area            Ward  \
# 0  Barking and Dagenham     Barking and Dagenham 001A  Chadwell Heath
# 1  Barking and Dagenham     Barking and Dagenham 001A  Chadwell Heath
# 2  Barking and Dagenham     Barking and Dagenham 001A  Chadwell Heath
# 3  Barking and Dagenham     Barking and Dagenham 001A  Chadwell Heath
# 4  Barking and Dagenham     Barking and Dagenham 001A  Chadwell Heath
#
#   Postcode Postcode district  London zone   Latitude  Longitude  \
# 0  RM6 5PU               RM6            5  51.587985   0.134785
# 1  RM6 5LJ               RM6            5  51.584118   0.137387
# 2  RM6 5QJ               RM6            5  51.588871   0.140933
# 3  RM6 5NB               RM6            5  51.586918   0.133147
# 4  RM6 5ND               RM6            5  51.587073   0.131523
#
#    Average Income  Total Crimes  Index of Multiple Deprivation  \
# 0           43600           334                           5097
# 1           43600           334                           5097
# 2           43600           334                           5097
# 3           43600           334                           5097
# 4           43600           334                           5097
#
#                Rural/urban  Average Rent Price  Budget-Friendly Rent Price  \
# 1                         False          False             False
# 2                         False          False             False
# 3                         False          False             False
# 4                         False          False             False
#
#    Second_Hindu  Second_Jewish  Second_Muslim (Islam)  Second_No religion  \
# 0         False          False                  False                True
# 1         False          False                  False                True
# 2         False          False                  False                True
# 3         False          False                  False                True
# 4         False          False                  False                True
#
#    Second_Religion not stated  Second_Sikh  Third_Christian  Third_Hindu  \
# 0                       False        False            False        False
# 1                       False        False            False        False
# 2                       False        False            False        False
# 3                       False        False            False        False
# 4                       False        False            False        False
#
#    Third_Jewish  Third_Muslim (Islam)  Third_No religion  \
# 0         False                 False              False
# 1         False                 False              False
# 2         False                 False              False
# 3         False                 False              False
# 4         False                 False              False
#
#    Third_Other religion  Third_Religion not stated  Third_Sikh  \
# 0                 False                       True       False
# 1                 False                       True       False
# 2                 False                       True       False
# 3                 False                       True       False
# 4                 False                       True       False
#
#    Majority_African  Majority_Any other ethnic group  Majority_Arab  \
# 0             False                            False          False
# 1             False                            False          False
# 2             False                            False          False
# 3             False                            False          False
# 4             False                            False          False
#
#    Majority_Australian/New Zealander  \
# 0                              False
# 1                              False
# 2                              False
# 3                              False
# 4                              False
#
#    Majority_Bangladeshi, British Bangladeshi  Majority_Caribbean  \
# 0                                      False                True
# 1                                      False                True
# 2                                      False                True
# 3                                      False                True
# 4                                      False                True
#
#    Majority_Chinese  Majority_Greek  Majority_Indian or British Indian  \
# 0             False           False                              False
# 1             False           False                              False
# 2             False           False                              False
# 3             False           False                              False
# 4             False           False                              False
#
#    Majority_Irish  Majority_Korean  Majority_Other Western European  \
# 0           False            False                            False
# 1           False            False                            False
# 2           False            False                            False
# 3           False            False                            False
# 4           False            False                            False
#
#    Majority_Pakistani or British Pakistani  Majority_Sri Lankan  \
# 0                                    False                False
# 1                                    False                False
# 2                                    False                False
# 3                                    False                False
# 4                                    False                False
#
#    Majority_Turkish  Majority_White and Asian  Second_Afghan  Second_African  \
# 0             False                     False          False            True
# 1             False                     False          False            True
# 2             False                     False          False            True
# 3             False                     False          False            True
# 4             False                     False          False            True
#
#    Second_Any other ethnic group  Second_Arab  \
# 0                          False        False
# 1                          False        False
# 2                          False        False
# 3                          False        False
# 4                          False        False
#
#    Second_Australian/New Zealander  Second_Bangladeshi, British Bangladeshi  \
# 0                            False                                    False
# 1                            False                                    False
# 2                            False                                    False
# 3                            False                                    False
# 4                            False                                    False
#
#    Second_Black British  Second_Caribbean  Second_Chinese  \
# 0                 False             False           False
# 1                 False             False           False
# 2                 False             False           False
# 3                 False             False           False
# 4                 False             False           False
#
#    Second_English/Welsh/Scottish/Northern Irish/British  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Second_European Mixed  Second_Filipino  Second_Greek  Second_Greek Cypriot  \
# 0                  False            False         False                 False
# 1                  False            False         False                 False
# 2                  False            False         False                 False
# 3                  False            False         False                 False
# 4                  False            False         False                 False
#
#    Second_Indian or British Indian  Second_Irish  Second_Japanese  \
# 0                            False         False            False
# 1                            False         False            False
# 2                            False         False            False
# 3                            False         False            False
# 4                            False         False            False
#
#    Second_Korean  Second_North American  Second_Other Western European  \
# 0          False                  False                          False
# 1          False                  False                          False
# 2          False                  False                          False
# 3          False                  False                          False
# 4          False                  False                          False
#
#    Second_Pakistani or British Pakistani  Second_Sri Lankan  Second_Turkish  \
# 0                                  False              False           False
# 1                                  False              False           False
# 2                                  False              False           False
# 3                                  False              False           False
# 4                                  False              False           False
#
#    Second_White and Black Caribbean  Third_African  \
# 0                             False          False
# 1                             False          False
# 2                             False          False
# 3                             False          False
# 4                             False          False
#
#    Third_Any other ethnic group  Third_Arab  Third_Australian/New Zealander  \
# 0                         False       False                           False
# 1                         False       False                           False
# 2                         False       False                           False
# 3                         False       False                           False
# 4                         False       False                           False
#
#    Third_Bangladeshi, British Bangladeshi  Third_Black British  \
# 0                                   False                 True
# 1                                   False                 True
# 2                                   False                 True
# 3                                   False                 True
# 4                                   False                 True
#
#    Third_Caribbean  Third_Chinese  \
# 0            False          False
# 1            False          False
# 2            False          False
# 3            False          False
# 4            False          False
#
#    Third_English/Welsh/Scottish/Northern Irish/British  Third_European Mixed  \
# 0                                              False                   False
# 1                                              False                   False
# 2                                              False                   False
# 3                                              False                   False
# 4                                              False                   False
#
#    Third_Greek  Third_Greek Cypriot  Third_Indian or British Indian  \
# 0        False                False                           False
# 1        False                False                           False
# 2        False                False                           False
# 3        False                False                           False
# 4        False                False                           False
#
#    Third_Irish  Third_Japanese  Third_Korean  Third_North American  \
# 0        False           False         False                 False
# 1        False           False         False                 False
# 2        False           False         False                 False
# 3        False           False         False                 False
# 4        False           False         False                 False
#
#    Third_Other Western European  Third_Pakistani or British Pakistani  \
# 0                         False                                 False
# 1                         False                                 False
# 2                         False                                 False
# 3                         False                                 False
# 4                         False                                 False
#
#    Third_Polish  Third_Sri Lankan  Third_Turkish  Third_White and Asian  \
# 0         False             False          False                  False
# 1         False             False          False                  False
# 2         False             False          False                  False
# 3         False             False          False                  False
# 4         False             False          False                  False
#
#    Third_White and Black Caribbean  Cluster_Labels
# 0                            False               2
# 1                            False               2
# 2                            False               2
# 3                            False               2
# 4                            False               2

# %%
# Apply KMeans clustering
kmeans = KMeans(n_clusters=5, random_state=42)
kmeans.fit(dfSubset_final)
labels = kmeans.labels_

# Further reduce the dimensionality to 2 components for visualization
pca_for_visualization = PCA(n_components=2)
dfSubset_visualization = pca_for_visualization.fit_transform(dfSubset_final)

# Plotting the clusters
plt.figure(figsize=(12, 8))
scatter = plt.scatter(dfSubset_visualization[:, 0], dfSubset_visualization[:, 1], c=labels, cmap='viridis', marker='o')

# Plot the centroids from dfSubset_visualization
centroids = kmeans.cluster_centers_
centroids_visualization = pca_for_visualization.transform(centroids)
plt.scatter(centroids_visualization[:, 0], centroids_visualization[:, 1], c='red', s=200, alpha=0.75, marker='x')

# Adding titles and labels
plt.title('Visualising Clusters of London Neighbourhoods')
plt.xlabel('First Principal Direction')
plt.ylabel('Second Principal Direction')

# Adding legend for cluster labels
plt.legend(*scatter.legend_elements(), title="Clusters")

plt.show()
# Out:
# /Users/alessandrosuarez_/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/alessandrosuarez_/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but PCA was fitted with feature names
#   warnings.warn(

# %%
# Silhouette average score and plot
silhouette_avg = silhouette_score(dfSubset_final, cluster_labels)
print(f"The average silhouette_score is : {silhouette_avg}")

# Compute the silhouette scores for each sample
sample_silhouette_values = silhouette_samples(dfSubset_final, cluster_labels)

# Create a subplot with 1 row and 1 column
fig, ax1 = plt.subplots(1)
fig.set_size_inches(18, 7)

# The 1st subplot is the silhouette plot
# The silhouette coefficient can range from -1, 1
ax1.set_xlim([-0.1, 1])
# The (n_clusters+1)*10 is for inserting blank space between silhouette plots of individual clusters, to demarcate them clearly.
ax1.set_ylim([0, len(dfSubset_final) + (kmeans.n_clusters + 1) * 10])

y_lower = 10
for i in range(kmeans.n_clusters):  
    # Aggregate the silhouette scores for samples belonging to cluster i, and sort them
    ith_cluster_silhouette_values = \
        sample_silhouette_values[cluster_labels == i]

    ith_cluster_silhouette_values.sort()

    size_cluster_i = ith_cluster_silhouette_values.shape[0]
    y_upper = y_lower + size_cluster_i

    color = cm.nipy_spectral(float(i) / kmeans.n_clusters) 
    ax1.fill_betweenx(np.arange(y_lower, y_upper),
                      0, ith_cluster_silhouette_values,
                      facecolor=color, edgecolor=color, alpha=0.7)

    # Label the silhouette plots with their cluster numbers at the middle
    ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

    # Compute the new y_lower for next plot
    y_lower = y_upper + 10  

ax1.set_title("The silhouette plot for the various clusters.")
ax1.set_xlabel("The silhouette coefficient values")
ax1.set_ylabel("Cluster label")

# The vertical line for average silhouette score of all the values
ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

ax1.set_yticks([])  
ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

plt.suptitle(("Silhouette analysis for KMeans clustering on sample data "
              f"with n_clusters = {kmeans.n_clusters}"),
             fontsize=14, fontweight='bold')

plt.show()
# Out:
# The average silhouette_score is : 0.10610636294716894

# %% [markdown]
# ### DBSCAN

# %%
# Initialize DBSCAN with eps and min_samples parameters
# Starting point (eps=0.9, min_samples=5) it did not perform well
dbscan = DBSCAN(eps=4, min_samples=5) # The best cluster with these parameters

# Fit the model data
dbscan.fit(dfSubset_final)

# The labels_ attribute provide the assigned cluster labels
dbscan_labels = dbscan.labels_

# DBSCAN cluster labels as a new column in the DataFrame
df['DBSCAN_Cluster_Labels'] = dbscan_labels

# Check how many unique clusters were created
n_clusters_ = len(set(dbscan_labels)) - (1 if -1 in dbscan_labels else 0)
n_noise_ = list(dbscan_labels).count(-1)

print(f'Estimated number of clusters: {n_clusters_}')
print(f'Estimated number of noise points: {n_noise_}')

# To see the first few entries with their respective cluster assignments
df.head()
# Out:
# Estimated number of clusters: 659
# Estimated number of noise points: 3
#                District Lower layer super output area            Ward  \
# 0  Barking and Dagenham     Barking and Dagenham 001A  Chadwell Heath
# 1  Barking and Dagenham     Barking and Dagenham 001A  Chadwell Heath
# 2  Barking and Dagenham     Barking and Dagenham 001A  Chadwell Heath
# 3  Barking and Dagenham     Barking and Dagenham 001A  Chadwell Heath
# 4  Barking and Dagenham     Barking and Dagenham 001A  Chadwell Heath
#
#   Postcode Postcode district  London zone   Latitude  Longitude  \
# 0  RM6 5PU               RM6            5  51.587985   0.134785
# 1  RM6 5LJ               RM6            5  51.584118   0.137387
# 2  RM6 5QJ               RM6            5  51.588871   0.140933
# 3  RM6 5NB               RM6            5  51.586918   0.133147
# 4  RM6 5ND               RM6            5  51.587073   0.131523
#
#    Average Income  Total Crimes  Index of Multiple Deprivation  \
# 0           43600           334                           5097
# 1           43600           334                           5097
# 3                    False                 False
# 4                    False                 False
#
#    Majority_Religion not stated  Majority_Sikh  Second_Christian  \
# 0                         False          False             False
# 1                         False          False             False
# 2                         False          False             False
# 3                         False          False             False
# 4                         False          False             False
#
#    Second_Hindu  Second_Jewish  Second_Muslim (Islam)  Second_No religion  \
# 0         False          False                  False                True
# 1         False          False                  False                True
# 2         False          False                  False                True
# 3         False          False                  False                True
# 4         False          False                  False                True
#
#    Second_Religion not stated  Second_Sikh  Third_Christian  Third_Hindu  \
# 0                       False        False            False        False
# 1                       False        False            False        False
# 2                       False        False            False        False
# 3                       False        False            False        False
# 4                       False        False            False        False
#
#    Third_Jewish  Third_Muslim (Islam)  Third_No religion  \
# 0         False                 False              False
# 1         False                 False              False
# 2         False                 False              False
# 3         False                 False              False
# 4         False                 False              False
#
#    Third_Other religion  Third_Religion not stated  Third_Sikh  \
# 0                 False                       True       False
# 1                 False                       True       False
# 2                 False                       True       False
# 3                 False                       True       False
# 4                 False                       True       False
#
#    Majority_African  Majority_Any other ethnic group  Majority_Arab  \
# 0             False                            False          False
# 1             False                            False          False
# 2             False                            False          False
# 3             False                            False          False
# 4             False                            False          False
#
#    Majority_Australian/New Zealander  \
# 0                              False
# 1                              False
# 2                              False
# 3                              False
# 4                              False
#
#    Majority_Bangladeshi, British Bangladeshi  Majority_Caribbean  \
# 0                                      False                True
# 1                                      False                True
# 2                                      False                True
# 3                                      False                True
# 4                                      False                True
#
#    Majority_Chinese  Majority_Greek  Majority_Indian or British Indian  \
# 0             False           False                              False
# 1             False           False                              False
# 2             False           False                              False
# 3             False           False                              False
# 4             False           False                              False
#
#    Majority_Irish  Majority_Korean  Majority_Other Western European  \
# 0           False            False                            False
# 1           False            False                            False
# 2           False            False                            False
# 3           False            False                            False
# 4           False            False                            False
#
#    Majority_Pakistani or British Pakistani  Majority_Sri Lankan  \
# 0                                    False                False
# 1                                    False                False
# 2                                    False                False
# 3                                    False                False
# 4                                    False                False
#
#    Majority_Turkish  Majority_White and Asian  Second_Afghan  Second_African  \
# 0             False                     False          False            True
# 1             False                     False          False            True
# 2             False                     False          False            True
# 3             False                     False          False            True
# 4             False                     False          False            True
#
#    Second_Any other ethnic group  Second_Arab  \
# 0                          False        False
# 1                          False        False
# 2                          False        False
# 3                          False        False
# 4                          False        False
#
#    Second_Australian/New Zealander  Second_Bangladeshi, British Bangladeshi  \
# 0                            False                                    False
# 1                            False                                    False
# 2                            False                                    False
# 3                            False                                    False
# 4                            False                                    False
#
#    Second_Black British  Second_Caribbean  Second_Chinese  \
# 0                 False             False           False
# 1                 False             False           False
# 2                 False             False           False
# 3                 False             False           False
# 4                 False             False           False
#
#    Second_English/Welsh/Scottish/Northern Irish/British  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Second_European Mixed  Second_Filipino  Second_Greek  Second_Greek Cypriot  \
# 0                  False            False         False                 False
# 1                  False            False         False                 False
# 2                  False            False         False                 False
# 3                  False            False         False                 False
# 4                  False            False         False                 False
#
#    Second_Indian or British Indian  Second_Irish  Second_Japanese  \
# 0                            False         False            False
# 1                            False         False            False
# 2                            False         False            False
# 3                            False         False            False
# 4                            False         False            False
#
#    Second_Korean  Second_North American  Second_Other Western European  \
# 0          False                  False                          False
# 1          False                  False                          False
# 2          False                  False                          False
# 3          False                  False                          False
# 4          False                  False                          False
#
#    Second_Pakistani or British Pakistani  Second_Sri Lankan  Second_Turkish  \
# 0                                  False              False           False
# 1                                  False              False           False
# 2                                  False              False           False
# 3                                  False              False           False
# 4                                  False              False           False
#
#    Second_White and Black Caribbean  Third_African  \
# 0                             False          False
# 1                             False          False
# 2                             False          False
# 3                             False          False
# 4                             False          False
#
#    Third_Any other ethnic group  Third_Arab  Third_Australian/New Zealander  \
# 0                         False       False                           False
# 1                         False       False                           False
# 2                         False       False                           False
# 3                         False       False                           False
# 4                         False       False                           False
#
#    Third_Bangladeshi, British Bangladeshi  Third_Black British  \
# 0                                   False                 True
# 1                                   False                 True
# 2                                   False                 True
# 3                                   False                 True
# 4                                   False                 True
#
#    Third_Caribbean  Third_Chinese  \
# 0            False          False
# 1            False          False
# 2            False          False
# 3            False          False
# 4            False          False
#
#    Third_English/Welsh/Scottish/Northern Irish/British  Third_European Mixed  \
# 0                                              False                   False
# 1                                              False                   False
# 2                                              False                   False
# 3                                              False                   False
# 4                                              False                   False
#
#    Third_Greek  Third_Greek Cypriot  Third_Indian or British Indian  \
# 0        False                False                           False
# 1        False                False                           False
# 2        False                False                           False
# 3        False                False                           False
# 4        False                False                           False
#
#    Third_Irish  Third_Japanese  Third_Korean  Third_North American  \
# 0        False           False         False                 False
# 1        False           False         False                 False
# 2        False           False         False                 False
# 3        False           False         False                 False
# 4        False           False         False                 False
#
#    Third_Other Western European  Third_Pakistani or British Pakistani  \
# 0                         False                                 False
# 1                         False                                 False
# 2                         False                                 False
# 3                         False                                 False
# 4                         False                                 False
#
#    Third_Polish  Third_Sri Lankan  Third_Turkish  Third_White and Asian  \
# 0         False             False          False                  False
# 1         False             False          False                  False
# 2         False             False          False                  False
# 3         False             False          False                  False
# 4         False             False          False                  False
#
#    Third_White and Black Caribbean  Cluster_Labels  DBSCAN_Cluster_Labels
# 0                            False               2                      0
# 1                            False               2                      0
# 2                            False               2                      0
# 3                            False               2                      0
# 4                            False               2                      0

# %%
# DBSCAN Plot
# Initialise PCA to reduce the data to 2 components for visualisation
pca_2d = PCA(n_components=2)

# Fit and transform the data
reduced_data = pca_2d.fit_transform(dfSubset_final)
plt.figure(figsize=(10, 8))

# Plotting each cluster
unique_labels = set(dbscan_labels)
for label in unique_labels:
    # Selecting data points that belong to the current label
    points = reduced_data[dbscan_labels == label]
    
    # Noise points are labeled as -1
    if label == -1:
        color = 'k'  # black for noise
    else:
        color = plt.cm.nipy_spectral(float(label) / len(unique_labels))  # other specific color for clusters
    
    # Plot points
    plt.scatter(points[:, 0], points[:, 1], s=5, color=color, label=f'Cluster {label}' if label != -1 else 'Noise')

# Adding titles and labels
#plt.legend(loc='best')
plt.title('Visualising DBSCAN Clustering of London Neighbourhoods')
plt.xlabel('First Principal Direction')
plt.ylabel('Second Principal Direction')
plt.show()
